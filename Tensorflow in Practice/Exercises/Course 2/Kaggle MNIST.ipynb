# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop

# %%
raw_data = pd.read_csv("/train.csv")

# %%
X =  raw_data.iloc[0:42000,1:].values.reshape(42000,28,28,1)
y = raw_data.iloc[0:42000,0:1].values.reshape(42000,)

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(16,(3,3),activation="relu",input_shape=(28,28,1)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    tf.keras.layers.Conv2D(32,(3,3),activation="relu"),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(units=512,activation="relu"),
                                    tf.keras.layers.Dense(10,activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               410112
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 420,042
# Trainable params: 420,042
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer=RMSprop(lr=0.001),metrics=["acc"])

# %%
model.fit(X,y,epochs=15)
# Out:
# Train on 42000 samples
# Epoch 1/15
# 42000/42000 [==============================] - 8s 183us/sample - loss: 0.6382 - acc: 0.9402
# Epoch 2/15
# 42000/42000 [==============================] - 8s 181us/sample - loss: 0.0931 - acc: 0.9781
# Epoch 3/15
# 42000/42000 [==============================] - 8s 180us/sample - loss: 0.0725 - acc: 0.9831
# Epoch 4/15
# 42000/42000 [==============================] - 8s 181us/sample - loss: 0.0624 - acc: 0.9858
# Epoch 5/15
# 42000/42000 [==============================] - 8s 183us/sample - loss: 0.0567 - acc: 0.9876
# Epoch 6/15
# 42000/42000 [==============================] - 7s 178us/sample - loss: 0.0557 - acc: 0.9889
# Epoch 7/15
# 42000/42000 [==============================] - 8s 181us/sample - loss: 0.0495 - acc: 0.9895
# Epoch 8/15
# 42000/42000 [==============================] - 8s 180us/sample - loss: 0.0481 - acc: 0.9903
# Epoch 9/15
# 42000/42000 [==============================] - 8s 182us/sample - loss: 0.0516 - acc: 0.9903
# Epoch 10/15
# 42000/42000 [==============================] - 7s 178us/sample - loss: 0.0436 - acc: 0.9925
# Epoch 11/15
# 42000/42000 [==============================] - 8s 180us/sample - loss: 0.0428 - acc: 0.9929
# Epoch 12/15
# 42000/42000 [==============================] - 8s 180us/sample - loss: 0.0425 - acc: 0.9931
# Epoch 13/15
# 42000/42000 [==============================] - 8s 180us/sample - loss: 0.0463 - acc: 0.9927
# Epoch 14/15
# 42000/42000 [==============================] - 8s 179us/sample - loss: 0.0382 - acc: 0.9947
# Epoch 15/15
# 42000/42000 [==============================] - 8s 182us/sample - loss: 0.0426 - acc: 0.9942
